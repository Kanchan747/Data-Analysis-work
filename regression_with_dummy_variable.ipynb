# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b01dbc8b-b4b3-4800-8cf6-d80a2f851d02" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b01dbc8b-b4b3-4800-8cf6-d80a2f851d02">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_csv('DSC_503_regression with dummy variables.csv')
df
# Out:
#         ses    math  size  gender
# 0    -1.528   5.876   842  Female
# 1    -0.588  19.708   842  Female
# 2    -0.528  20.349   842    Male
# 3    -0.668   8.781   842    Male
# 4    -0.158  17.898   842    Male
# ...     ...     ...   ...     ...
# 7180  1.512  20.402   262  Female
# 7181 -0.038  14.794   262  Female
# 7182  1.332  19.641   262  Female
# 7183 -0.008  16.241   262  Female
# 7184  0.792  22.733   262  Female
#
# [7185 rows x 4 columns]

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
print(df.head(6))
# Out:
#      ses    math  size  gender
# 0 -1.528   5.876   842  Female
# 1 -0.588  19.708   842  Female
# 2 -0.528  20.349   842    Male
# 3 -0.668   8.781   842    Male
# 4 -0.158  17.898   842    Male
# 5  0.022   4.583   842    Male

# %%
model_ols_dummy = ols("math ~ ses + size + C(gender)", data=df).fit()

# %%
print(model_ols_dummy.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   math   R-squared:                       0.141
# Model:                            OLS   Adj. R-squared:                  0.141
# Method:                 Least Squares   F-statistic:                     392.5
# Date:                Mon, 24 Mar 2025   Prob (F-statistic):          4.49e-236
# Time:                        15:11:29   Log-Likelihood:                -23504.
# No. Observations:                7185   AIC:                         4.702e+04
# Df Residuals:                    7181   BIC:                         4.704e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept            12.4657      0.165     75.363      0.000      12.141      12.790
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0583b139-e0ca-4017-98c3-633520d15996" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0583b139-e0ca-4017-98c3-633520d15996">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_csv('DSC_503_training.csv')

# %%
df
# Out:
#      experience  work_hours  training_type  productivity_score
# 0      5.751550   38.121986              0           67.960703
# 1     15.766103   37.190618              0           87.489616
# 2      8.179538   38.280414              1          100.000000
# 3     17.660348   40.452483              1          100.000000
# 4     18.809346   47.992544              0           89.269741
# ..          ...         ...            ...                 ...
# 495   19.858880   28.946834              0           99.474208
# 496    5.061980   53.458570              1           97.623294
# 497    0.990769   37.586616              0           68.351312
# 498   13.726499   51.873674              1          100.000000
# 499   15.738547   41.873218              1          100.000000
#
# [500 rows x 4 columns]

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
model_ols_dummy = ols("productivity_score ~ experience + work_hours + C(training_type)", data=df).fit()

# %%
print(model_ols_dummy.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:     productivity_score   R-squared:                       0.773
# Model:                            OLS   Adj. R-squared:                  0.772
# Method:                 Least Squares   F-statistic:                     563.9
# Date:                Mon, 24 Mar 2025   Prob (F-statistic):          2.26e-159
# Time:                        15:17:45   Log-Likelihood:                -1603.9
# No. Observations:                 500   AIC:                             3216.
# Df Residuals:                     496   BIC:                             3233.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                63.7842      2.228     28.631      0.000      59.407      68.161
# ...

# %%
# prompt: regression graph

import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'model_ols_dummy' is your fitted OLS model

# Extract predicted values and actual values
c  # Replace 'productivity_score' with your dependent variable

# Create a scatter plot
plt.figure(figsize=(8, 6))
sns.scatterplot(x=predicted_values, y=actual_values)
plt.xlabel('Predicted Productivity Score')
plt.ylabel('Actual Productivity Score')
plt.title('Regression Plot: Productivity Score vs. Predicted Productivity Score')

# Add a regression line (optional)
sns.regplot(x=predicted_values, y=actual_values, scatter=False, color='red')

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
