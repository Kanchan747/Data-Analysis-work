# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9985b855-5bcc-4caf-b7bd-ce9bd608b55d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9985b855-5bcc-4caf-b7bd-ce9bd608b55d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_csv('DSC_503_regression with interaction terms.csv')
df
# Out:
#         ses       math  size  gender
# 0    -1.528   7.246106   842  Female
# 1    -0.588  20.961401   842  Female
# 2    -0.528  17.737760   842    Male
# 3    -0.668   6.839923   842    Male
# 4    -0.158  19.500945   842    Male
# ...     ...        ...   ...     ...
# 7180  1.512  19.263174   262  Female
# 7181 -0.038  16.717387   262  Female
# 7182  1.332  21.598064   262  Female
# 7183 -0.008  16.778957   262  Female
# 7184  0.792  20.381224   262  Female
#
# [7185 rows x 4 columns]

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
model_ols_interaction = ols("math ~ size + ses*C(gender)", data=df).fit()
print(model_ols_interaction.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   math   R-squared:                       0.219
# Model:                            OLS   Adj. R-squared:                  0.218
# Method:                 Least Squares   F-statistic:                     502.9
# Date:                Mon, 31 Mar 2025   Prob (F-statistic):               0.00
# Time:                        14:43:03   Log-Likelihood:                -23830.
# No. Observations:                7185   AIC:                         4.767e+04
# Df Residuals:                    7180   BIC:                         4.770e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                12.5635      0.173     72.536      0.000      12.224      12.903
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c980637c-7cbd-40b3-a782-0b880b4856a4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c980637c-7cbd-40b3-a782-0b880b4856a4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_csv('DSC_503_store.csv')
df
# Out:
#      customer_traffic  store_size  location_type  monthly_revenue
# 0            5.751550   38.121986              0        67.960703
# 1           15.766103   37.190618              0        87.489616
# 2            8.179538   38.280414              1       100.000000
# 3           17.660348   40.452483              1       100.000000
# 4           18.809346   47.992544              0        89.269741
# ..                ...         ...            ...              ...
# 495         19.858880   28.946834              0        99.474208
# 496          5.061980   53.458570              1        97.623294
# 497          0.990769   37.586616              0        68.351312
# 498         13.726499   51.873674              1       100.000000
# 499         15.738547   41.873218              1       100.000000
#
# [500 rows x 4 columns]

# %%
model_ols_interaction = ols("monthly_revenue ~ store_size + customer_traffic*C(location_type)", data=df).fit()
print(model_ols_interaction.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:        monthly_revenue   R-squared:                       0.802
# Model:                            OLS   Adj. R-squared:                  0.800
# Method:                 Least Squares   F-statistic:                     499.8
# Date:                Mon, 31 Mar 2025   Prob (F-statistic):          3.02e-172
# Time:                        14:58:53   Log-Likelihood:                -1570.7
# No. Observations:                 500   AIC:                             3151.
# Df Residuals:                     495   BIC:                             3172.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                                              coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------
# ...

# %%
# !pip install rpy2
# %load_ext rpy2.ipython

# %%
# %%R
# # simple R example
# x <- c(1, 2, 3, 4, 5)
# mean(x)
# Out:
# [1] 3

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3c6487b4-17ee-4442-9f85-89aad7d7782b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3c6487b4-17ee-4442-9f85-89aad7d7782b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# %%R
# data <- read.csv("DSC_503_multilevel.csv")
# summary(data)
# Out:
#      school       SES             math_score
#  Min.   :1   Min.   :-1.96662   Min.   :33.85
#  1st Qu.:2   1st Qu.:-0.47126   1st Qu.:47.48
#  Median :3   Median : 0.04107   Median :53.93
#  Mean   :3   Mean   : 0.06382   Mean   :54.77
#  3rd Qu.:4   3rd Qu.: 0.69818   3rd Qu.:60.20
#  Max.   :5   Max.   : 2.16896   Max.   :77.03

# %%
# %%R
# install.packages("lmerTest")
# library(lmerTest)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
# also installing the dependency ‘lme4’
#
# trying URL 'https://cran.rstudio.com/src/contrib/lme4_1.1-37.tar.gz'
# Content type 'application/x-gzip' length 3313529 bytes (3.2 MB)
# ...
# downloaded 3.2 MB
#
# trying URL 'https://cran.rstudio.com/src/contrib/lmerTest_3.1-3.tar.gz'
# Content type 'application/x-gzip' length 195633 bytes (191 KB)
# ...
# downloaded 191 KB
#
#
# The downloaded source packages are in
# 	‘/tmp/RtmpPyg3mK/downloaded_packages’
# Loading required package: lme4
# Loading required package: Matrix
#
# Attaching package: ‘lmerTest’
#
# The following object is masked from ‘package:lme4’:
#
#     lmer
#
# The following object is masked from ‘package:stats’:
#
#     step

# %%
# %%R
# install.packages("lmertest")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
# In addition: Warning messages:
# 1: package ‘lmertest’ is not available for this version of R
#
# A version of this package for your version of R might be available elsewhere,
# see the ideas at
# https://cran.r-project.org/doc/manuals/r-patched/R-admin.html#Installing-packages
# 2: Perhaps you meant ‘lmerTest’ ?

# %%
# %%R
# # Install necessary packages if not already installed
# if(!require(lme4)){install.packages("lme4")}
# if(!require(lmerTest)){install.packages("lmerTest")}
# Out:
# Exception ignored from cffi callback <function _processevents at 0x7dfb4280a840>:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/rpy2/rinterface_lib/callbacks.py", line 283, in _processevents
#     @ffi_proxy.callback(ffi_proxy._processevents_def,
#
# KeyboardInterrupt:
# Loading required package: lme4
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
# trying URL 'https://cran.rstudio.com/src/contrib/lme4_1.1-37.tar.gz'
# Content type 'application/x-gzip' length 3313529 bytes (3.2 MB)
# ...
# downloaded 3.2 MB
#
#
# The downloaded source packages are in
# 	‘/tmp/RtmprpEdd1/downloaded_packages’
# Loading required package: lmerTest
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
# also installing the dependencies ‘lme4’, ‘numDeriv’
#
# trying URL 'https://cran.rstudio.com/src/contrib/lme4_1.1-37.tar.gz'
# Content type 'application/x-gzip' length 3313529 bytes (3.2 MB)
# ...

# %%
# %%R
# install.packages("lmerTest")
# library(lmerTest)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
# trying URL 'https://cran.rstudio.com/src/contrib/lmerTest_3.1-3.tar.gz'
# Content type 'application/x-gzip' length 195633 bytes (191 KB)
# ...
# downloaded 191 KB
#
#
# The downloaded source packages are in
# 	‘/tmp/RtmpPyg3mK/downloaded_packages’

# %%
# %%R
# install.packages("lme4")
# library(lme4)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
# trying URL 'https://cran.rstudio.com/src/contrib/lme4_1.1-37.tar.gz'
# Content type 'application/x-gzip' length 3313529 bytes (3.2 MB)
# ...
# downloaded 3.2 MB
#
#
# The downloaded source packages are in
# 	‘/tmp/RtmpPyg3mK/downloaded_packages’
# In addition: Warning message:
# In install.packages("lme4") :
#   installation of package ‘lme4’ had non-zero exit status

# %%
# %%R
# model <- lmer(math_score ~ SES + (1 + SES | school), data = data)
# summary(model)
# Out:
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: math_score ~ SES + (1 + SES | school)
#    Data: data
#
# REML criterion at convergence: 279.8
#
# Scaled residuals:
#      Min       1Q   Median       3Q      Max
# -2.16693 -0.62283 -0.06738  0.50780  2.36626
#
# Random effects:
#  Groups   Name        Variance Std.Dev. Corr
#  school   (Intercept) 17.681   4.205
#           SES          3.788   1.946    -0.73
#  Residual             12.849   3.585
# Number of obs: 50, groups:  school, 5
#
# Fixed effects:
#             Estimate Std. Error     df t value Pr(>|t|)
# (Intercept)   54.027      1.952  3.920  27.677 1.21e-05 ***
# SES            9.440      1.070  4.115   8.822    8e-04 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#     (Intr)
# SES -0.591

# %%
# %%R
# ranef(model)
# Out:
# $school
#   (Intercept)        SES
# 1   5.1458255 -2.3670665
# 2   0.8231595 -1.0999116
# 3  -5.8221009  1.4716969
# 4   1.4339356  0.7442517
# 5  -1.5808196  1.2510296
#
# with conditional variances for “school”

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e00bc80b-8a00-443a-b00d-36211bd3026a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e00bc80b-8a00-443a-b00d-36211bd3026a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# %%R
# df <- read.csv("DSC_503_multilevel_exercise (1).csv")
# head(df)
# Out:
#   store training_hours sales_revenue
# 1     1      6.3506939      72.01765
# 2     1      8.4739746      85.02719
# 3     1      0.8592277      65.09899
# 4     1      2.5854769      75.98498
# 5     1      1.5362882      68.00344
# 6     1      1.5683914      76.55819

# %%
# %%R
# install.packages("lmerTest")
# library(lmerTest)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
# trying URL 'https://cran.rstudio.com/src/contrib/lmerTest_3.1-3.tar.gz'
# Content type 'application/x-gzip' length 195633 bytes (191 KB)
# ...
# downloaded 191 KB
#
#
# The downloaded source packages are in
# 	‘/tmp/RtmpPyg3mK/downloaded_packages’

# %%
# %%R
# model <- lmer(sales_revenue ~ training_hours + (1+ training_hours | store), data = df)
# summary(model)
# Out:
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: sales_revenue ~ training_hours + (1 + training_hours | store)
#    Data: df
#
# REML criterion at convergence: 519.2
#
# Scaled residuals:
#      Min       1Q   Median       3Q      Max
# -2.16996 -0.54371  0.05853  0.53191  2.60363
#
# Random effects:
#  Groups   Name           Variance Std.Dev. Corr
#  store    (Intercept)    109.4548 10.4621
#           training_hours   0.5683  0.7538  0.84
#  Residual                 21.7622  4.6650
# Number of obs: 80, groups:  store, 10
#
# Fixed effects:
#                Estimate Std. Error      df t value Pr(>|t|)
# (Intercept)     50.5773     3.5948  9.1279  14.070  1.7e-07 ***
# training_hours   1.3356     0.2683  8.5126   4.978    9e-04 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#             (Intr)
# trainng_hrs 0.526

# %%
# %%R
# ranef(model)
# Out:
# $store
#     (Intercept) training_hours
# 1   15.49398399      1.1946972
# 2   -6.65904476     -0.3696712
# 3   -7.54423811     -0.4022134
# 4   13.23230520      0.4711475
# 5   13.20296105      1.1116995
# 6   -1.15715474      0.1171483
# 7   -8.49404419     -0.4751412
# 8   -0.02832739     -0.1007368
# 9  -10.15554778     -0.9774590
# 10  -7.89089326     -0.5694709
#
# with conditional variances for “store”
