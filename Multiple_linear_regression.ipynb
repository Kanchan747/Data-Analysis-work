# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7ccb0df6-6ae2-4a1a-8a5b-4d8845c46224" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7ccb0df6-6ae2-4a1a-8a5b-4d8845c46224">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_csv("DSC_503_anova (1).csv")
print(df.head(6))
# Out:
#    school    math
# 0    1224   5.876
# 1    1224  19.708
# 2    1224  20.349
# 3    1224   8.781
# 4    1224  17.898
# 5    1224   4.583

# %%
# prompt: give me a syntax for creating blank table of 6 rows and 6 columns

import pandas as pd

# Create an empty DataFrame with 6 rows and 6 columns
empty_df = pd.DataFrame(index=range(6), columns=range(6))

empty_df
# Out:
#      0    1    2    3    4    5
# 0  NaN  NaN  NaN  NaN  NaN  NaN
# 1  NaN  NaN  NaN  NaN  NaN  NaN
# 2  NaN  NaN  NaN  NaN  NaN  NaN
# 3  NaN  NaN  NaN  NaN  NaN  NaN
# 4  NaN  NaN  NaN  NaN  NaN  NaN
# 5  NaN  NaN  NaN  NaN  NaN  NaN
# No charts were generated by quickchart

# %%
import pandas as pd

# Data to create the table
data = {'Name   ': ['Shubham', 'Avinash', 'Kanchan', 'Jatin  '],
        '    Maths Score': [100, 89, 78, 56      ]}

# Creating the DataFrame
df = pd.DataFrame(data)

# Display the table
print(df)
# Out:
#    Name         Maths Score
# 0  Shubham              100
# 1  Avinash               89
# 2  Kanchan               78
# 3  Jatin                 56

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-53fe9f4d-087e-4d6d-9709-2dd8a248821c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-53fe9f4d-087e-4d6d-9709-2dd8a248821c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_csv("DSC_503_correlation.csv")

# %%
df
# Out:
#         ses    math
# 0    -1.528   5.876
# 1    -0.588  19.708
# 2    -0.528  20.349
# 3    -0.668   8.781
# 4    -0.158  17.898
# ...     ...     ...
# 7180  1.512  20.402
# 7181 -0.038  14.794
# 7182  1.332  19.641
# 7183 -0.008  16.241
# 7184  0.792  22.733
#
# [7185 rows x 2 columns]

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
model_ols = ols("math ~ ses", data=df).fit()

# %%
print(model_ols.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   math   R-squared:                       0.130
# Model:                            OLS   Adj. R-squared:                  0.130
# Method:                 Least Squares   F-statistic:                     1075.
# Date:                Mon, 24 Feb 2025   Prob (F-statistic):          8.71e-220
# Time:                        16:35:32   Log-Likelihood:                -23549.
# No. Observations:                7185   AIC:                         4.710e+04
# Df Residuals:                    7183   BIC:                         4.712e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     12.7474      0.076    168.424      0.000      12.599      12.896
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-556bd576-8764-469d-ae78-609c262a6325" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-556bd576-8764-469d-ae78-609c262a6325">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_csv("DSC_503_multiple linear regression.csv")

# %%
df
# Out:
#         ses    math  size
# 0    -1.528   5.876   842
# 1    -0.588  19.708   842
# 2    -0.528  20.349   842
# 3    -0.668   8.781   842
# 4    -0.158  17.898   842
# ...     ...     ...   ...
# 7180  1.512  20.402   262
# 7181 -0.038  14.794   262
# 7182  1.332  19.641   262
# 7183 -0.008  16.241   262
# 7184  0.792  22.733   262
#
# [7185 rows x 3 columns]

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
model_ols_mul = ols("math ~ ses + size", data=df).fit()

# %%
print(model_ols_mul.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   math   R-squared:                       0.131
# Model:                            OLS   Adj. R-squared:                  0.131
# Method:                 Least Squares   F-statistic:                     540.6
# Date:                Mon, 03 Mar 2025   Prob (F-statistic):          2.01e-219
# Time:                        16:17:37   Log-Likelihood:                -23546.
# No. Observations:                7185   AIC:                         4.710e+04
# Df Residuals:                    7182   BIC:                         4.712e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     13.0660      0.153     85.554      0.000      12.767      13.365
# ...
